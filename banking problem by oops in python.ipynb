# %%
class BankAccount:

    def __init__(self, account_number, account_holder, balance=0):
        self.account_number = account_number
        self.account_holder = account_holder
        self.balance = balance
        self.transactions = []

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount

            self.transactions.append(
                ("Deposit", amount, self.balance)
            )

            print(f"₹{amount} deposited successfully.")
        else:
            print("Invalid amount.")

    def withdraw(self, amount):
        if amount <= 0:
            print("Invalid amount.")

        elif amount > self.balance:
            print("Insufficient balance.")

        else:
            self.balance -= amount

            self.transactions.append(
                ("Withdrawal", amount, self.balance)
            )

            print(f"₹{amount} withdrawn successfully.")

    def check_balance(self):
        print(f"Current Balance: ₹{self.balance}")

    def show_statement(self):
        print("\n----- BANK STATEMENT -----")
        print("Account Holder:", self.account_holder)
        print("Account Number:", self.account_number)

        print("\nTransaction History:")

        for transaction in self.transactions:
            transaction_type, amount, balance = transaction

            print(
                f"{transaction_type} | "
                f"Amount: ₹{amount} | "
                f"Balance: ₹{balance}"
            )

        print("--------------------------")


# Creating object
account = BankAccount(
    "ACC1001",
    "Arpan",
    10000
)

account.deposit(5000)
account.withdraw(2000)
account.deposit(3000)
account.withdraw(1500)

account.check_balance()

account.show_statement()
# Out:
# ₹5000 deposited successfully.
# ₹2000 withdrawn successfully.
# ₹3000 deposited successfully.
# ₹1500 withdrawn successfully.
# Current Balance: ₹14500
#
# ----- BANK STATEMENT -----
# Account Holder: Arpan
# Account Number: ACC1001
#
# Transaction History:
# Deposit | Amount: ₹5000 | Balance: ₹15000
# Withdrawal | Amount: ₹2000 | Balance: ₹13000
# Deposit | Amount: ₹3000 | Balance: ₹16000
# Withdrawal | Amount: ₹1500 | Balance: ₹14500
# --------------------------
